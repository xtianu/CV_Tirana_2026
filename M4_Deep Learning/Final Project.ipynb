# %% [markdown]
# <a href="https://colab.research.google.com/github/xtianu/CV_Tirana_2026/blob/main/M4_Deep%20Learning/Final%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 4: DEEP LEARNING

# %% [markdown]
# Christian Mata, PhD

# %% [markdown]
# # ** FINAL PROJECT**
#
# **Before starting:**
#
# - Create a GitHub repository to upload the solution of this exercise.
# - Read and practice with the proposed examples.
# - Share this GitHub link to your professor.
# christian.mata@upc.edu
#
# **INSTRUCTIONS**
#
# - Find on internet an example similar to our examples presented in class.
#
# - For default is mandatory to implement a Classification method.
# - You can use any repository and any opensource database (Keras, Kaggle... etc). Moreover, you can use a GitHub repositoris from internet, and you can use AI tools (chatGPT, Perpelity, Claude...).
# - If you try a segmentation algorithm, it will be appreciated as an additional mark.
#
# ** WORKING GROUPS **
# - You can create a group of a maximum of 4 people. You can work individual as well, 2 or 3 people.
# - Deadline: 7th of June (I give you an extra time ;-))
